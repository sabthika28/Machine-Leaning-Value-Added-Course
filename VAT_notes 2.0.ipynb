# %% [markdown]
# # Pandas
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.
#
# Data Science: is a branch of computer science where we study how to store, use and analyze data for deriving information from it.
#
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
import pandas as pd

# %%
ds={'names':['Tushar','Saran','Madhan','Sabari'],'marks':[95,89,93,98]}
x=pd.DataFrame(ds)
print(x)
# Out:
#     names  marks
# 0  Tushar     95
# 1   Saran     89
# 2  Madhan     93
# 3  Sabari     98

# %% [markdown]
# # Pandas Series
#
# Its like a 1d array holding data of any type
# Its like a column in a table
# Here the indices are used as label.
# Usually the index starts from 0.
# Index is used to access specific value from the series

# %%
ds=[90,95,89,65,88]
df=pd.Series(ds)
print(df)
# Out:
# 0    90
# 1    95
# 2    89
# 3    65
# 4    88
# dtype: int64

# %%
print(df[2])
# Out:
# 89

# %%
print(df[0])
# Out:
# 90

# %%
ds=[90,95,89,65,88]
df=pd.Series(ds,index=['T','E','M','S','SS'])
print(df)
# Out:
# T     90
# E     95
# M     89
# S     65
# SS    88
# dtype: int64

# %%
print(df[1])
# Out:
# 95

# %%
print(df['E'])
# Out:
# 95

# %%
ds={'T':90,'E':95,'M':89,'S':65,'SS':88}
df=pd.Series(ds)
print(df)
# Out:
# T     90
# E     95
# M     89
# S     65
# SS    88
# dtype: int64

# %% [markdown]
# # DataFrame
#
# It is a multidimensional table in which each column is a series.

# %%
print(df.loc['E'])
# Out:
# 95

# %%
print(df.loc[['E','M']])
# Out:
# E    95
# M    89
# dtype: int64

# %%
ds={'Tam':[90,86,98,100,87],'Eng':[95,89,93,98,79],'Mat':[89,95,79,90,100]}
df=pd.DataFrame(ds,index=['Test1','Test2','Test3','Test4','Test5'])
print(df)
# Out:
#        Tam  Eng  Mat
# Test1   90   95   89
# Test2   86   89   95
# Test3   98   93   79
# Test4  100   98   90
# Test5   87   79  100

# %%
print(df.loc['Test2'])
# Out:
# Tam    86
# Eng    89
# Mat    95
# Name: Test2, dtype: int64

# %%
df1=pd.read_csv("C:/Users/sabth/Documents/Book1.csv")
print(df1)
# Out:
#   Unnamed: 0  Tam  Eng  Mat
# 0      Test1   87   79  100
# 1      Test2  100   98   90
# 2      Test3   98   93   79
# 3      Test4   86   89   95
# 4      Test5   90   95   89

# %%
df=pd.read_csv("C:/Users/sabth/Downloads/marine-economy-account-2007-2021.csv")

# %%
print(df.to_string())
# Out:
#      year                       category                                 variable       units  magnitude                  source  data_value flag
# 0    2007      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        42.1    F
# 1    2008      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.4    F
# 2    2009      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.9    R
# 3    2010      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        40.8    F
# 4    2011      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.9    F
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows=9999
print(pd.options.display.max_rows)
# Out:
# 9999

# %%
print(df.head(10))
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 5  2012  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 6  2013  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 7  2014  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 8  2015  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 9  2016  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag
# 0  Proportion    Actual   LEED        42.1    F
# 1  Proportion    Actual   LEED        39.4    F
# ...

# %%
print(df.head())
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag
# 0  Proportion    Actual   LEED        42.1    F
# 1  Proportion    Actual   LEED        39.4    F
# 2  Proportion    Actual   LEED        39.9    R
# 3  Proportion    Actual   LEED        40.8    F
# 4  Proportion    Actual   LEED        39.9    F

# %%
print(df.tail())
# Out:
#      year              category                 variable   units magnitude  \
# 709  2017  Total marine economy  Wage and salary earners  Number    Actual
# 710  2018  Total marine economy  Wage and salary earners  Number    Actual
# 711  2019  Total marine economy  Wage and salary earners  Number    Actual
# 712  2020  Total marine economy  Wage and salary earners  Number    Actual
# 713  2021  Total marine economy  Wage and salary earners  Number    Actual
#
#     source  data_value flag
# 709   LEED     38082.0    R
# 710   LEED     38880.0    R
# 711   LEED     39867.0    R
# 712   LEED     40593.0    P
# 713   LEED     39474.0    P

# %%
print(df.tail(10))
# Out:
#      year              category                 variable   units magnitude  \
# 704  2012  Total marine economy  Wage and salary earners  Number    Actual
# 705  2013  Total marine economy  Wage and salary earners  Number    Actual
# 706  2014  Total marine economy  Wage and salary earners  Number    Actual
# 707  2015  Total marine economy  Wage and salary earners  Number    Actual
# 708  2016  Total marine economy  Wage and salary earners  Number    Actual
# 709  2017  Total marine economy  Wage and salary earners  Number    Actual
# 710  2018  Total marine economy  Wage and salary earners  Number    Actual
# 711  2019  Total marine economy  Wage and salary earners  Number    Actual
# 712  2020  Total marine economy  Wage and salary earners  Number    Actual
# 713  2021  Total marine economy  Wage and salary earners  Number    Actual
#
#     source  data_value flag
# 704   LEED     33894.0    R
# 705   LEED     33018.0    F
# 706   LEED     35070.0    R
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        714 non-null    int64
#  1   category    714 non-null    object
#  2   variable    714 non-null    object
#  3   units       714 non-null    object
#  4   magnitude   714 non-null    object
#  5   source      714 non-null    object
#  6   data_value  702 non-null    float64
#  7   flag        714 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 44.8+ KB
# None

# %% [markdown]
# # Data cleaning
#
# It is used to fix bad and irrelevant data in the datasets It removes empty cells,data in wrong format,wrong data,duplicates

# %%
df.isnull().sum()
# Out:
# year           0
# category       0
# variable       0
# units          0
# magnitude      0
# source         0
# data_value    12
# flag           0
# dtype: int64

# %%
df=df.dropna()
print(df.to_string())
# Out:
#      year                       category                                 variable       units  magnitude                  source  data_value flag
# 0    2007      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        42.1    F
# 1    2008      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.4    F
# 2    2009      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.9    R
# 3    2010      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        40.8    F
# 4    2011      Fisheries and aquaculture      Cont. to ME Wage and salary earners  Proportion     Actual                    LEED        39.9    F
# ...

# %%
df.dropna(inplace=True)
print(df)
# Out:
#      year                       category  \
# 0    2007      Fisheries and aquaculture
# 1    2008      Fisheries and aquaculture
# 2    2009      Fisheries and aquaculture
# 3    2010      Fisheries and aquaculture
# 4    2011      Fisheries and aquaculture
# 5    2012      Fisheries and aquaculture
# 6    2013      Fisheries and aquaculture
# 7    2014      Fisheries and aquaculture
# 8    2015      Fisheries and aquaculture
# 9    2016      Fisheries and aquaculture
# 10   2017      Fisheries and aquaculture
# 11   2018      Fisheries and aquaculture
# 12   2019      Fisheries and aquaculture
# 13   2020      Fisheries and aquaculture
# 14   2021      Fisheries and aquaculture
# 15   2007      Fisheries and aquaculture
# 16   2008      Fisheries and aquaculture
# 17   2009      Fisheries and aquaculture
# 18   2010      Fisheries and aquaculture
# 19   2011      Fisheries and aquaculture
# 20   2012      Fisheries and aquaculture
# 21   2013      Fisheries and aquaculture
# ...

# %%
df.fillna(10,inplace=True)
print(df)
# Out:
#      year                       category  \
# 0    2007      Fisheries and aquaculture
# 1    2008      Fisheries and aquaculture
# 2    2009      Fisheries and aquaculture
# 3    2010      Fisheries and aquaculture
# 4    2011      Fisheries and aquaculture
# 5    2012      Fisheries and aquaculture
# 6    2013      Fisheries and aquaculture
# 7    2014      Fisheries and aquaculture
# 8    2015      Fisheries and aquaculture
# 9    2016      Fisheries and aquaculture
# 10   2017      Fisheries and aquaculture
# 11   2018      Fisheries and aquaculture
# 12   2019      Fisheries and aquaculture
# 13   2020      Fisheries and aquaculture
# 14   2021      Fisheries and aquaculture
# 15   2007      Fisheries and aquaculture
# 16   2008      Fisheries and aquaculture
# 17   2009      Fisheries and aquaculture
# 18   2010      Fisheries and aquaculture
# 19   2011      Fisheries and aquaculture
# 20   2012      Fisheries and aquaculture
# 21   2013      Fisheries and aquaculture
# ...

# %%
df.columns
# Out:
# Index(['year', 'category', 'variable', 'units', 'magnitude', 'source',
#        'data_value', 'flag'],
#       dtype='object')

# %%
df["category"].fillna(10,inplace=True)
print(df)
# Out:
#      year                       category  \
# 0    2007      Fisheries and aquaculture
# 1    2008      Fisheries and aquaculture
# 2    2009      Fisheries and aquaculture
# 3    2010      Fisheries and aquaculture
# 4    2011      Fisheries and aquaculture
# 5    2012      Fisheries and aquaculture
# 6    2013      Fisheries and aquaculture
# 7    2014      Fisheries and aquaculture
# 8    2015      Fisheries and aquaculture
# 9    2016      Fisheries and aquaculture
# 10   2017      Fisheries and aquaculture
# 11   2018      Fisheries and aquaculture
# 12   2019      Fisheries and aquaculture
# 13   2020      Fisheries and aquaculture
# 14   2021      Fisheries and aquaculture
# 15   2007      Fisheries and aquaculture
# 16   2008      Fisheries and aquaculture
# 17   2009      Fisheries and aquaculture
# 18   2010      Fisheries and aquaculture
# 19   2011      Fisheries and aquaculture
# 20   2012      Fisheries and aquaculture
# 21   2013      Fisheries and aquaculture
# ...

# %% [markdown]
# # Ways to handle empty values

# %%
# y=df["SepalLengthCm"].median()
# z=df["PetalLengthCm"].mode()[0]

# %%
# df['data_value']=pd.to_integer(df['data_value'])

# %% [markdown]
# # Fixing wrong data
#
# To fix wrong values replace them with correct values
# set duration to 45 in row 7 which is wrongly typed as 450

# %%
# df.loc[7,"header"]=correct value
# df.drop(value,inplace=True)

# %% [markdown]
# #Removing duplicates
# #To discover duplicates,duplicated() method can be used
# #It returns True or False based on the data

# %%
# print(df.duplicated())
# df.drop_duplicates(inplace=True)

# %% [markdown]
# # Data Correlations
#
# Finding relationships: corr() method is used to find the relationship between each columns.

# %%
# df.corr()

# %% [markdown]
# Correlation is a number and it varies from -1 to 1

# %%
# df=pd.read_csv('D:/File.csv')
# df.plot()
# plt.show()

# %%
# plot(kind=scatter/hist)

# %%
# df[header].plot(kind='hist')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Plot function
#
# It draws a line from one point to another point.
# It has two parameters first paramater is x axis points and second parameter is y axis points

# %%
x=np.array([0,10,20])
y=np.array([0,100,200])
plt.plot(x,y,'o')

# %%
x=np.array([2,3,8,10])
y=np.array([4,9,3,12])
plt.plot(x,y)

# %%
y=np.array([2,3,8,10])
plt.plot(y)

# %%
plt.plot(y,marker='o')

# %%
plt.plot(y,marker='*')

# %%
plt.plot(y,marker='D')

# %% [markdown]
# Syntax: Marker|line style|colour Line style
# '-' Solid line ':' Dotted line '--' Dashed line '-.' Dashed/dotted line

# %% [markdown]
# 'r' Red 'g' Green 'b' Blue 'c' Cyan 'm' Magenta 'y' Yellow 'k' Black 'w' White

# %%
plt.plot(y,'D-g')

# %%
plt.plot(y,'D:g')

# %%
plt.plot(y,'D--r')

# %%
plt.plot(y,'D-.m')

# %%
plt.plot(y,'D-.y',ms=10)

# %%
plt.plot(y,'o-.g',ms=10,mec='b',mfc='r')

# %%
plt.plot(y,'o-.g',ms=10,mec='#ff00ff',mfc='#ffff00')

# %%
plt.plot(y,'o-.g',ms=10,mec='blue',mfc='pink')

# %%
plt.plot(y,linestyle='dashed')

# %%
plt.plot(y,ls=':')

# %%
plt.plot(y,ls='')

# %%
plt.plot(y,linestyle='dashed',c='b')

# %%
plt.plot(y,linestyle='dashed',c='b',lw=10)

# %%
y1=np.array([2,3,8,10])
y2=np.array([1,4,9,12])
plt.plot(y1,linestyle='-',c='b')
plt.plot(y2,linestyle='-',c='r')

# %%
x1=np.array([2,4,6,8])
x2=np.array([2,4,6,8])
y1=np.array([2,3,8,10])
y2=np.array([1,4,9,12])
plt.plot(x1,y1,x2,y2)

# %%
plt.title('ODI Ind vs Aus')
# Out:
# Text(0.5, 1.0, 'ODI Ind vs Aus')

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title('ODI Ind vs Aus',fontdict=font1,loc='left')#font and title location
plt.xlabel('overs',fontdict=font2)
plt.ylabel('runs',fontdict=font2)
# Out:
# Text(0, 0.5, 'runs')

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title('ODI Ind vs Aus',fontdict=font1,loc='left')#font and title location
plt.xlabel('overs',fontdict=font2)
plt.ylabel('runs',fontdict=font2)
plt.grid()

# %%
plt.grid(axis='x')

# %%
plt.grid(axis='y',c='g',ls='--',lw='0.5')
